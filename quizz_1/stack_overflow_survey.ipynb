# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/survey_results_public.csv")
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
# დავპრინტოთ პირველი 100 სტრიქონი
df.head(100)
# Out:
#     ResponseId     Q120                      MainBranch              Age  \
# 0            1  I agree                   None of these  18-24 years old
# 1            2  I agree  I am a developer by profession  25-34 years old
# 2            3  I agree  I am a developer by profession  45-54 years old
# 3            4  I agree  I am a developer by profession  25-34 years old
# 4            5  I agree  I am a developer by profession  25-34 years old
# ..         ...      ...                             ...              ...
# 95          96  I agree  I am a developer by profession  18-24 years old
# 96          97  I agree  I am a developer by profession  25-34 years old
# 97          98  I agree  I am a developer by profession  25-34 years old
# 98          99  I agree  I am a developer by profession  35-44 years old
# 99         100  I agree  I am a developer by profession  25-34 years old
#
#                                            Employment  \
# 0                                                 NaN
# 1                                 Employed, full-time
# 2                                 Employed, full-time
# 3                                 Employed, full-time
# 4   Employed, full-time;Independent contractor, fr...
# ..                                                ...
# 95                                Employed, full-time
# 96                                Employed, full-time
# 97                                Employed, full-time
# 98             Employed, part-time;Student, part-time
# 99  Employed, full-time;Independent contractor, fr...
#
#                               RemoteWork  \
# 0                                    NaN
# 1                                 Remote
# 2   Hybrid (some remote, some in-person)
# 3   Hybrid (some remote, some in-person)
# 4                                 Remote
# ..                                   ...
# 95                             In-person
# 96  Hybrid (some remote, some in-person)
# 97                             In-person
# 98  Hybrid (some remote, some in-person)
# 99                             In-person
#
#                                      CodingActivities  \
# 0                                                 NaN
# 1   Hobby;Contribute to open-source projects;Boots...
# 2   Hobby;Professional development or self-paced l...
# 3                                               Hobby
# 4   Hobby;Contribute to open-source projects;Profe...
# ..                                                ...
# 95  Hobby;Professional development or self-paced l...
# 96                                              Hobby
# 97                                              Hobby
# 98           Hobby;Contribute to open-source projects
# 99                      Hobby;Freelance/contract work
#
#                                               EdLevel  \
# 0                                                 NaN
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ..                                                ...
# 95       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 96       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 97  Some college/university study without earning ...
# 98       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 99    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                             LearnCode  \
# 0                                                 NaN
# 1   Books / Physical media;Colleague;Friend or fam...
# 2   Books / Physical media;Colleague;On the job tr...
# 3   Colleague;Friend or family member;Other online...
# 4   Books / Physical media;Online Courses or Certi...
# ..                                                ...
# 95  Books / Physical media;Hackathons (virtual or ...
# 96                                          Colleague
# 97  Colleague;Online Courses or Certification;On t...
# 98  Books / Physical media;Other online resources ...
# 99  Books / Physical media;Online Courses or Certi...
#
#                                       LearnCodeOnline  ...        Frequency_1  \
# 0                                                 NaN  ...                NaN
# 1   Formal documentation provided by the owner of ...  ...   1-2 times a week
# 2   Formal documentation provided by the owner of ...  ...  6-10 times a week
# 3   Formal documentation provided by the owner of ...  ...   1-2 times a week
# 4   Formal documentation provided by the owner of ...  ...   1-2 times a week
# ..                                                ...  ...                ...
# 95  Formal documentation provided by the owner of ...  ...                NaN
# 96                                                NaN  ...   1-2 times a week
# 97                                                NaN  ...   1-2 times a week
# 98  Formal documentation provided by the owner of ...  ...                NaN
# 99  Formal documentation provided by the owner of ...  ...   1-2 times a week
#
#           Frequency_2       Frequency_3               TimeSearching  \
# 0                 NaN               NaN                         NaN
# 1    10+ times a week             Never         15-30 minutes a day
# 2   6-10 times a week  3-5 times a week         30-60 minutes a day
# 3    10+ times a week  1-2 times a week         15-30 minutes a day
# 4    1-2 times a week  3-5 times a week        60-120 minutes a day
# ..                ...               ...                         ...
# 95                NaN               NaN                         NaN
# 96   3-5 times a week  1-2 times a week         30-60 minutes a day
# 97              Never             Never        60-120 minutes a day
# 98                NaN               NaN                         NaN
# 99   10+ times a week  10+ times a week  Less than 15 minutes a day
#
#              TimeAnswering                                   ProfessionalTech  \
# 0                      NaN                                                NaN
# 1      15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 2      30-60 minutes a day  DevOps function;Microservices;Automated testin...
# 3      30-60 minutes a day  Automated testing;Continuous integration (CI) ...
# 4      30-60 minutes a day  Microservices;Automated testing;Observability ...
# ..                     ...                                                ...
# 95                     NaN                                                NaN
# 96     15-30 minutes a day  DevOps function;Microservices;Automated testin...
# 97     30-60 minutes a day                                    DevOps function
# 98                     NaN                                                NaN
# 99  Over 120 minutes a day    Microservices;Observability tools;None of these
#
#                                              Industry           SurveyLength  \
# 0                                                 NaN                    NaN
# 1   Information Services, IT, Software Development...  Appropriate in length
# 2   Information Services, IT, Software Development...  Appropriate in length
# 3                                                 NaN  Appropriate in length
# 4                                               Other  Appropriate in length
# ..                                                ...                    ...
# 95                                                NaN  Appropriate in length
# 96                       Retail and Consumer Services               Too long
# 97  Information Services, IT, Software Development...  Appropriate in length
# 98                                                NaN  Appropriate in length
# 99                       Retail and Consumer Services  Appropriate in length
#
#                     SurveyEase ConvertedCompYearly
# 0                          NaN                 NaN
# 1                         Easy            285000.0
# 2                         Easy            250000.0
# 3                         Easy            156000.0
# 4   Neither easy nor difficult             23456.0
# ..                         ...                 ...
# 95  Neither easy nor difficult               371.0
# 96  Neither easy nor difficult             86528.0
# 97  Neither easy nor difficult                 NaN
# 98                        Easy                 NaN
# 99  Neither easy nor difficult             30842.0
#
# [100 rows x 84 columns]

# %%
# შევამოწმოთ დატაფრეიმის სვეტები
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
#        'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith',
#        'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm',
#        'SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
#        'AIToolInterested in Using', 'AIToolCurrently Using',
#        'AIToolNot interested in Using', 'AINextVery different',
#        'AINextNeither different nor similar', 'AINextSomewhat similar',
#        'AINextVery similar', 'AINextSomewhat different', 'TBranch', 'ICorPM',
#        'WorkExp', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
#        'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching',
#        'TimeAnswering', 'ProfessionalTech', 'Industry', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# გამოვიტანოთ სასურველი სვეტი
learned_online = df["LearnCodeOnline"]
learned_online
# Out:
# 0                                                      NaN
# 1        Formal documentation provided by the owner of ...
# 2        Formal documentation provided by the owner of ...
# 3        Formal documentation provided by the owner of ...
# 4        Formal documentation provided by the owner of ...
#                                ...
# 89179    Formal documentation provided by the owner of ...
# 89180    Formal documentation provided by the owner of ...
# 89181                                                  NaN
# 89182    Formal documentation provided by the owner of ...
# 89183    Formal documentation provided by the owner of ...
# Name: LearnCodeOnline, Length: 89184, dtype: object

# %%
# დავაინდექსოთ დატაფრეიმი
df.set_index("ResponseId", inplace=True)

# %%
# გავფილტორთ დატა ასაკისა და სამუშაო გამოცდილების მიხედვით
filt = (df['Age'] == '18-24 years old') & (df['WorkExp']>5)
df.loc[filt]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 115         I agree  I am a developer by profession  18-24 years old
# 165         I agree  I am a developer by profession  18-24 years old
# 249         I agree  I am a developer by profession  18-24 years old
# 258         I agree  I am a developer by profession  18-24 years old
# 283         I agree  I am a developer by profession  18-24 years old
# ...             ...                             ...              ...
# 88667       I agree  I am a developer by profession  18-24 years old
# 88745       I agree  I am a developer by profession  18-24 years old
# 88884       I agree  I am a developer by profession  18-24 years old
# 88983       I agree  I am a developer by profession  18-24 years old
# 89125       I agree  I am a developer by profession  18-24 years old
#
#                                                    Employment  \
# ResponseId
# 115         Employed, full-time;Independent contractor, fr...
# 165                                       Employed, full-time
# 249         Employed, full-time;Independent contractor, fr...
# 258                                       Employed, part-time
# 283                                       Employed, full-time
# ...                                                       ...
# 88667                  Employed, full-time;Student, full-time
# 88745                                     Employed, full-time
# 88884                                     Employed, full-time
# 88983                                     Employed, full-time
# 89125                                     Employed, part-time
#
#                                       RemoteWork  \
# ResponseId
# 115                                    In-person
# 165         Hybrid (some remote, some in-person)
# 249                                       Remote
# 258                                       Remote
# 283                                    In-person
# ...                                          ...
# 88667                                  In-person
# 88745                                     Remote
# 88884                                     Remote
# 88983                                     Remote
# 89125                                     Remote
#
#                                              CodingActivities  \
# ResponseId
# 115         Hobby;Professional development or self-paced l...
# 165                             Hobby;School or academic work
# 249         Hobby;Contribute to open-source projects;Boots...
# 258         Hobby;Contribute to open-source projects;Boots...
# 283         Bootstrapping a business;Professional developm...
# ...                                                       ...
# 88667       Hobby;Professional development or self-paced l...
# 88745       Hobby;Contribute to open-source projects;Profe...
# 88884                                 Freelance/contract work
# 88983                            I don’t code outside of work
# 89125       Hobby;Contribute to open-source projects;Freel...
#
#                                                       EdLevel  \
# ResponseId
# 115              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 165              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 249         Some college/university study without earning ...
# 258              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 283         Some college/university study without earning ...
# ...                                                       ...
# 88667            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 88745       Secondary school (e.g. American high school, G...
# 88884       Secondary school (e.g. American high school, G...
# 88983                               Primary/elementary school
# 89125            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 115         Colleague;Online Courses or Certification;On t...
# 165         Friend or family member;Online Courses or Cert...
# 249                                   Other (please specify):
# 258         Books / Physical media;On the job training;Sch...
# 283         On the job training;Other online resources (e....
# ...                                                       ...
# 88667       Colleague;Online Courses or Certification;On t...
# 88745       Books / Physical media;Other online resources ...
# 88884                                 Friend or family member
# 88983                  Books / Physical media;Coding Bootcamp
# 89125       Books / Physical media;Other online resources ...
#
#                                               LearnCodeOnline  \
# ResponseId
# 115         Formal documentation provided by the owner of ...
# 165         Formal documentation provided by the owner of ...
# 249                                                       NaN
# 258                                                       NaN
# 283         Formal documentation provided by the owner of ...
# ...                                                       ...
# 88667       Formal documentation provided by the owner of ...
# 88745       Formal documentation provided by the owner of ...
# 88884                                                     NaN
# 88983                                                     NaN
# 89125       Formal documentation provided by the owner of ...
#
#            LearnCodeCoursesCert  ...        Frequency_1       Frequency_2  \
# ResponseId                       ...
# 115                       Udemy  ...                NaN               NaN
# 165              Udemy;Coursera  ...              Never  1-2 times a week
# 249                         NaN  ...   3-5 times a week  3-5 times a week
# 258                         NaN  ...   1-2 times a week  1-2 times a week
# 283                         NaN  ...              Never  10+ times a week
# ...                         ...  ...                ...               ...
# 88667                     Udemy  ...   3-5 times a week  10+ times a week
# 88745                       NaN  ...   1-2 times a week  10+ times a week
# 88884                       NaN  ...  6-10 times a week  3-5 times a week
# 88983                       NaN  ...              Never  1-2 times a week
# 89125                       NaN  ...   1-2 times a week             Never
#
#                  Frequency_3               TimeSearching  \
# ResponseId
# 115                      NaN        60-120 minutes a day
# 165         1-2 times a week         15-30 minutes a day
# 249         1-2 times a week         30-60 minutes a day
# 258         1-2 times a week         30-60 minutes a day
# 283         1-2 times a week         15-30 minutes a day
# ...                      ...                         ...
# 88667       1-2 times a week        60-120 minutes a day
# 88745       1-2 times a week         30-60 minutes a day
# 88884       3-5 times a week         30-60 minutes a day
# 88983       1-2 times a week  Less than 15 minutes a day
# 89125                  Never         30-60 minutes a day
#
#                          TimeAnswering  \
# ResponseId
# 115               60-120 minutes a day
# 165                15-30 minutes a day
# 249                30-60 minutes a day
# 258                15-30 minutes a day
# 283               60-120 minutes a day
# ...                                ...
# 88667              30-60 minutes a day
# 88745              15-30 minutes a day
# 88884              30-60 minutes a day
# 88983              15-30 minutes a day
# 89125       Less than 15 minutes a day
#
#                                              ProfessionalTech  \
# ResponseId
# 115         DevOps function;Continuous integration (CI) an...
# 165                                             Microservices
# 249         DevOps function;Microservices;Automated testin...
# 258                                             None of these
# 283         DevOps function;Microservices;Observability to...
# ...                                                       ...
# 88667       DevOps function;Continuous integration (CI) an...
# 88745       Microservices;Automated testing;Continuous int...
# 88884                                           Microservices
# 88983                           DevOps function;Microservices
# 89125                       DevOps function;Automated testing
#
#                                                      Industry  \
# ResponseId
# 115                                          Higher Education
# 165         Information Services, IT, Software Development...
# 249         Information Services, IT, Software Development...
# 258         Information Services, IT, Software Development...
# 283         Information Services, IT, Software Development...
# ...                                                       ...
# 88667       Information Services, IT, Software Development...
# 88745                                        Higher Education
# 88884                                      Financial Services
# 88983                                          Legal Services
# 89125       Information Services, IT, Software Development...
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 115                      Too long  Neither easy nor difficult
# 165         Appropriate in length                        Easy
# 249         Appropriate in length  Neither easy nor difficult
# 258                     Too short                        Easy
# 283                      Too long                        Easy
# ...                           ...                         ...
# 88667       Appropriate in length  Neither easy nor difficult
# 88745       Appropriate in length                        Easy
# 88884       Appropriate in length                         NaN
# 88983       Appropriate in length                        Easy
# 89125                    Too long                        Easy
#
#             ConvertedCompYearly
# ResponseId
# 115                         NaN
# 165                     52046.0
# 249                    223449.0
# 258                     16063.0
# 283                      7087.0
# ...                         ...
# 88667                       NaN
# 88745                   14607.0
# 88884                       NaN
# 88983                       NaN
# 89125                       NaN
#
# [415 rows x 83 columns]

# %%
# დავასორტიროთ დატაფრეიმი ასაკისა და წლიური შემოსავლის მიხედვით
df.sort_values(by=['Age', 'ConvertedCompYearly'], ascending=[True, False])
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 53269       I agree  I am a developer by profession     18-24 years old
# 80587       I agree  I am a developer by profession     18-24 years old
# 34997       I agree  I am a developer by profession     18-24 years old
# 82593       I agree  I am a developer by profession     18-24 years old
# 81524       I agree  I am a developer by profession     18-24 years old
# ...             ...                             ...                 ...
# 89066       I agree     I code primarily as a hobby  Under 18 years old
# 89075       I agree     I code primarily as a hobby  Under 18 years old
# 89097       I agree           I am learning to code  Under 18 years old
# 89135       I agree     I code primarily as a hobby  Under 18 years old
# 89183       I agree  I am a developer by profession  Under 18 years old
#
#                                                    Employment  \
# ResponseId
# 53269       Independent contractor, freelancer, or self-em...
# 80587       Employed, full-time;Independent contractor, fr...
# 34997                                     Employed, full-time
# 82593       Independent contractor, freelancer, or self-em...
# 81524                                     Employed, full-time
# ...                                                       ...
# 89066                  Not employed, and not looking for work
# 89075                                      Student, full-time
# 89097                  Not employed, and not looking for work
# 89135                                      Student, full-time
# 89183                  Employed, part-time;Student, part-time
#
#                                       RemoteWork  \
# ResponseId
# 53269       Hybrid (some remote, some in-person)
# 80587       Hybrid (some remote, some in-person)
# 34997                                     Remote
# 82593                                     Remote
# 81524                                     Remote
# ...                                          ...
# 89066                                        NaN
# 89075                                        NaN
# 89097                                        NaN
# 89135                                        NaN
# 89183       Hybrid (some remote, some in-person)
#
#                                              CodingActivities  \
# ResponseId
# 53269       Hobby;Contribute to open-source projects;Boots...
# 80587       Hobby;Contribute to open-source projects;Boots...
# 34997                                                   Hobby
# 82593                                 Freelance/contract work
# 81524       Hobby;Professional development or self-paced l...
# ...                                                       ...
# 89066                                                     NaN
# 89075                                                     NaN
# 89097                                                     NaN
# 89135                                                     NaN
# 89183                           Hobby;School or academic work
#
#                                                       EdLevel  \
# ResponseId
# 53269          Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 80587            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34997            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 82593            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 81524            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 89066                               Primary/elementary school
# 89075       Secondary school (e.g. American high school, G...
# 89097       Secondary school (e.g. American high school, G...
# 89135                               Primary/elementary school
# 89183       Secondary school (e.g. American high school, G...
#
#                                                     LearnCode  \
# ResponseId
# 53269       Friend or family member;Online Courses or Cert...
# 80587       Hackathons (virtual or in-person);Other online...
# 34997       Other online resources (e.g., videos, blogs, f...
# 82593       Other online resources (e.g., videos, blogs, f...
# 81524       Online Courses or Certification;Other online r...
# ...                                                       ...
# 89066       Books / Physical media;Colleague;Online Course...
# 89075       Online Courses or Certification;Other online r...
# 89097       Other online resources (e.g., videos, blogs, f...
# 89135                                                     NaN
# 89183       Online Courses or Certification;Other online r...
#
#                                               LearnCodeOnline  \
# ResponseId
# 53269       Formal documentation provided by the owner of ...
# 80587       Formal documentation provided by the owner of ...
# 34997       Formal documentation provided by the owner of ...
# 82593       Blogs with tips and tricks;How-to videos;Video...
# 81524       Formal documentation provided by the owner of ...
# ...                                                       ...
# 89066                                                     NaN
# 89075       Formal documentation provided by the owner of ...
# 89097       Recorded coding sessions;How-to videos;Click t...
# 89135                                                     NaN
# 89183       Formal documentation provided by the owner of ...
#
#            LearnCodeCoursesCert  ...       Frequency_1       Frequency_2  \
# ResponseId                       ...
# 53269                       NaN  ...  1-2 times a week  10+ times a week
# 80587                       NaN  ...               NaN               NaN
# 34997                       NaN  ...  1-2 times a week  1-2 times a week
# 82593                       NaN  ...               NaN               NaN
# 81524               Other;Udemy  ...  1-2 times a week  1-2 times a week
# ...                         ...  ...               ...               ...
# 89066                       NaN  ...               NaN               NaN
# 89075                       NaN  ...               NaN               NaN
# 89097                       NaN  ...               NaN               NaN
# 89135                       NaN  ...               NaN               NaN
# 89183                     Udemy  ...               NaN               NaN
#
#                  Frequency_3        TimeSearching        TimeAnswering  \
# ResponseId
# 53269                  Never  15-30 minutes a day  15-30 minutes a day
# 80587                    NaN                  NaN                  NaN
# 34997       1-2 times a week  30-60 minutes a day  15-30 minutes a day
# 82593                    NaN                  NaN                  NaN
# 81524       1-2 times a week  30-60 minutes a day  15-30 minutes a day
# ...                      ...                  ...                  ...
# 89066                    NaN                  NaN                  NaN
# 89075                    NaN                  NaN                  NaN
# 89097                    NaN                  NaN                  NaN
# 89135                    NaN                  NaN                  NaN
# 89183                    NaN                  NaN                  NaN
#
#                                              ProfessionalTech  \
# ResponseId
# 53269       Developer portal or other central places to fi...
# 80587                                                     NaN
# 34997       DevOps function;Automated testing;Continuous i...
# 82593                                                     NaN
# 81524       DevOps function;Microservices;Automated testin...
# ...                                                       ...
# 89066                                                     NaN
# 89075                                                     NaN
# 89097                                                     NaN
# 89135                                                     NaN
# 89183                                                     NaN
#
#                                                      Industry  \
# ResponseId
# 53269       Information Services, IT, Software Development...
# 80587                                                     NaN
# 34997                                              Healthcare
# 82593                                                     NaN
# 81524       Information Services, IT, Software Development...
# ...                                                       ...
# 89066                                                     NaN
# 89075                                                     NaN
# 89097                                                     NaN
# 89135                                                     NaN
# 89183                                                     NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 53269       Appropriate in length  Neither easy nor difficult
# 80587       Appropriate in length  Neither easy nor difficult
# 34997       Appropriate in length  Neither easy nor difficult
# 82593                    Too long  Neither easy nor difficult
# 81524       Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 89066                   Too short                        Easy
# 89075       Appropriate in length                        Easy
# 89097       Appropriate in length  Neither easy nor difficult
# 89135       Appropriate in length                        Easy
# 89183       Appropriate in length  Neither easy nor difficult
#
#             ConvertedCompYearly
# ResponseId
# 53269                74351432.0
# 80587                11000000.0
# 34997                 7435143.0
# 82593                 2141791.0
# 81524                 2028761.0
# ...                         ...
# 89066                       NaN
# 89075                       NaN
# 89097                       NaN
# 89135                       NaN
# 89183                       NaN
#
# [89184 rows x 83 columns]

# %%
# დავითვალოთ გამოცდილი დეველოპერების მინიმალური და მაქსიმალური ხელფასები
filt = df['WorkExp']>10
filtered_df = df.loc[filt]
max_salary = max(filtered_df.CompTotal)
min_salary = min(filtered_df.CompTotal)
min_salary, max_salary
# Out:
# (0.0, 1e+21)

# %%
# ავაგოთ ჩარტი: ტოპ 10 დატაბეისი რომელთანაც დეველოპერებს უმუშავიათ
df_copy = df.copy()
df_copy['DatabaseHaveWorkedWith'] = df_copy['DatabaseHaveWorkedWith'].fillna('')
df_copy['DatabaseHaveWorkedWith'] = df_copy['DatabaseHaveWorkedWith'].str.split(';')

database_counts = {}

for databases in df_copy['DatabaseHaveWorkedWith']:
    for database in databases:
        if database:
            database_counts[database] = database_counts.get(database, 0) + 1

database_counts = dict(sorted(database_counts.items(), key=lambda item: item[1], reverse=True))

plt.figure(figsize=(10, 6))
plt.bar(list(database_counts.keys())[:10], list(database_counts.values())[:10])
plt.title('Top 10 Most Used Databases')
plt.xlabel('Database')
plt.ylabel('Number of Users')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# ავაგოთ ჩარტი: ქართველი დეველოპერები ასაკის მიხედვით
georgia_data = df[df['Country'] == 'Georgia']

georgia_data = georgia_data.dropna(subset=['Age'])

plt.figure(figsize=(10, 6))
plt.plot(georgia_data['Age'].value_counts().sort_index(), marker='o', linestyle='-')
plt.title('Developer Ages in Georgia')
plt.xlabel('Age')
plt.ylabel('Number of Developers')
plt.grid(True)
plt.tight_layout()
plt.show()
